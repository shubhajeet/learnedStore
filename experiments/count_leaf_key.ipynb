# %%
import matplotlib.pyplot as plt
import sys
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Extract data
#
# Code to extract leaf_key_stats from the log file

# %%
df = pd.read_csv('/tmp/inmem_64_load.csv', header=None,delimiter=' ')

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(df[0], df[1], 'o-', label='inmem_64_load')
ax.set_xlabel('Number of leaf node')
ax.set_ylabel('Number of keys')
# Out:
# Text(0, 0.5, 'Number of keys')

# %%
df = pd.read_csv("/tmp/inmem_64_load_ran.csv", header=None, delimiter=' ')

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(df[0], df[1], 'o-', label='inmem_64_load')
ax.set_xlabel('Number of leaf node')
ax.set_ylabel('Number of keys')
# Out:
# Text(0, 0.5, 'Number of keys')
